# %% [markdown]
# <a href="https://colab.research.google.com/github/javierCruzTrejo/Practica_entregar/blob/main/Figura_Geometrica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
def area_cuadrado(L):
  area=L**2
  return  print('el area del cuadrado es: ', area)
    
def area_circulo(R):
  area=math.pi*R**2
  return print('el area del circulo es %.3f ' % area)

def area_triangulo(b,h):
  area=b*h/2
  return print('El area del triángulo es: ', area)

def area_trapecio(B,b,h):
  area=(B+b)*h/2
  return print('El area del Trapecio es: ', area)

def area_rectangulo(b,h):
  area=b*h
  return print('El area del Rectángulo es: ', area)

def area_elipse(a,b):
  area=a*b*math.pi
  return print('El area de la elipse es %.3f ' % area)
  
  opcion = 0
  while True:
    print("""
    Escoja la figura:
    1) Cuadrado
    2) Circulo
    3) Tringualos
    4) Trapecio
    5) Rectangulo
    6) Elipse
    """)
    opcion = int(input("Elige una opción: ") )     

    if opcion == 1:
      print(" ")
      L=int(input('Ingrese el lado: '))
      area_cuadrado(L)     
    elif opcion == 2:
      print(" ")
      R=int(input('Ingrese el radio del circulo: '))
      area_circulo(R)
    elif opcion == 3:
      print(" ")
      b=int(input('Ingrese la base: '))
      h=int(input('Ingrese la altura: '))
      area_triangulo(b,h)
    elif opcion == 4:
      B=int(input('Ingrese la base 1:'))
      b=int(input('Ingrese la base 2: '))
      h=int(input('Ingrese la altura: '))
      area_trapecio(B,b,h)
    elif opcion == 5:
      b=int(input('Ingrese la base: '))
      h=int(input('Ingrese la altura: '))
      area_rectangulo(b,h)
    elif opcion == 6:
      a=int(input('Ingrese el eje menor: '))
      b=int(input('Ingrese el eje mayor: '))
      area_elipse(a,b)
    elif opcion == 7:
        break
    else:
        print("Opción incorrecta")

# %%
import math
def area_cuadrado(L):
  area=L**2
  return  print('el area del cuadrado es: ', area)
    
def area_circulo(R):
  area=math.pi*R**2
  return print('el area del circulo es %.3f ' % area)

def area_triangulo(b,h):
  area=b*h/2
  return print('El area del triángulo es: ', area)

def area_trapecio(B,b,h):
  area=(B+b)*h/2
  return print('El area del Trapecio es: ', area)

def area_rectangulo(b,h):
  area=b*h
  return print('El area del Rectángulo es: ', area)

def area_elipse(a,b):
  area=a*b*math.pi
  return print('El area de la elipse es %.3f ' % area)
  
opcion = 0
while True:
  print("""
  Escoja la figura:
  1) Cuadrado  
  2) Circulo
  3) Tringualos
  4) Trapecio
  5) Rectangulo
  6) Elipse
  """)
  opcion = int(input("Elige una opción: ") )     
  
  if opcion == 1:
    print(" ")
    L=int(input('Ingrese el lado: '))
    area_cuadrado(L)     
  elif opcion == 2:
    print(" ")
    R=int(input('Ingrese el radio del circulo: '))
    area_circulo(R)
  elif opcion == 3:
    print(" ")
    b=int(input('Ingrese la base: '))
    h=int(input('Ingrese la altura: '))
    area_triangulo(b,h)
  elif opcion == 4:
    B=int(input('Ingrese la base 1:'))
    b=int(input('Ingrese la base 2: '))
    h=int(input('Ingrese la altura: '))
    area_trapecio(B,b,h)
  elif opcion == 5:
    b=int(input('Ingrese la base: '))
    h=int(input('Ingrese la altura: '))
    area_rectangulo(b,h)
  elif opcion == 6:
    a=int(input('Ingrese el eje menor: '))
    b=int(input('Ingrese el eje mayor: '))
    area_elipse(a,b)
  elif opcion == 7:
    break
  else:
        print("Opción incorrecta")
# Out:
#   Escoja la figura:
#   1) Cuadrado
#   2) Circulo
#   3) Tringualos
#   4) Trapecio
#   5) Rectangulo
#   6) Elipse
#
# Elige una opción: 1
#
# Ingrese el lado: 5
# el area del cuadrado es:  25
#
#   Escoja la figura:
#   1) Cuadrado
#   2) Circulo
#   3) Tringualos
#   4) Trapecio
#   5) Rectangulo
#   6) Elipse
#
# Elige una opción: 2
#
# Ingrese el radio del circulo: 65
# el area del circulo es 13273.229
#
#   Escoja la figura:
#   1) Cuadrado
#   2) Circulo
#   3) Tringualos
#   4) Trapecio
#   5) Rectangulo
#   6) Elipse
#
# Elige una opción: 3
#
# Ingrese la base: 5
# Ingrese la altura: 4
# El area del triángulo es:  10.0
#
#   Escoja la figura:
#   1) Cuadrado
#   2) Circulo
#   3) Tringualos
#   4) Trapecio
#   5) Rectangulo
#   6) Elipse
#
# Elige una opción: 5
# Ingrese la base: 9
# Ingrese la altura: 5
# El area del Rectángulo es:  45
#
#   Escoja la figura:
#   1) Cuadrado
#   2) Circulo
#   3) Tringualos
#   4) Trapecio
#   5) Rectangulo
#   6) Elipse
#
# Elige una opción: 6
# Ingrese el eje menor: 4
# Ingrese el eje mayor: 8
# El area de la elipse es 100.531
#
#   Escoja la figura:
#   1) Cuadrado
#   2) Circulo
#   3) Tringualos
#   4) Trapecio
#   5) Rectangulo
#   6) Elipse
